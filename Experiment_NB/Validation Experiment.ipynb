# %%
# %load_ext rpy2.ipython

# %%
# %%bash
# export WD=./Simulation_result
# export CONF=$(pwd)/Exp_conf_test
# export SCRIPT=$(pwd)/../Simulation_Script/simulation.py
#
# mkdir ./Experiment_out
# mkdir $WD
# cd $WD
#
# for CONFIG in $CONF/*.json
# do
#     python3 $SCRIPT $CONFIG
# done
# Out:
# TensorFlow version: 1.10.0
# TensorFlow version: 1.10.0
# TensorFlow version: 1.10.0
# TensorFlow version: 1.10.0
# 2019-06-26 14:35:55.495248: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# 2019-06-26 14:36:46.783855: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# 2019-06-26 14:37:44.268417: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# 2019-06-26 14:38:37.991469: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA

# %%
# %%R
#
# groups <- list.dirs(path = "./Simulation_result", full.names = TRUE, recursive = FALSE)
#
# datalist <- c()
# x <- c("Group","Experiment", "Pattern", "Peak", "Path")
# for (group in groups){
#     group_name <- basename(group)
#     experiments <- list.dirs(path = group, full.names = TRUE, recursive = FALSE)
#     for (experiment in experiments){
#         exp_name <- basename(experiment)
#         patterns <- list.dirs(path = experiment, full.names = TRUE, recursive = FALSE)
#         for (pattern in patterns) {
#             pattern_name<-basename(pattern)
#             peaks <- list.dirs(path = pattern, full.names = TRUE, recursive = FALSE)
#             for (peak in peaks) {
#                 peak_name<-basename(peak)
#                 peak_file <- list.files(path = peak, full.names = TRUE, recursive = FALSE)[1]
#                 datalist <- rbind(datalist, c(group_name, exp_name, pattern_name, peak_name, peak_file))
#             }
#         }
#     }
# }
#
# datadf = data.frame(datalist)
# colnames(datadf) <- x

# %%
# %%R
# library(MMDiff3)
# library(reshape2)
# library(ggplot2)
# library(GenomicRanges)
# library(DiffBind)
# library(devtools)
# Out:
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: Loading required package: Rsamtools
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: Loading required package: GenomeInfoDb
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: Loading required package: BiocGenerics
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: Loading required package: parallel
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning:
# Attaching package: ‘BiocGenerics’
#
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: The following objects are masked from ‘package:parallel’:
#
#     clusterApply, clusterApplyLB, clusterCall, clusterEvalQ,
#     clusterExport, clusterMap, parApply, parCapply, parLapply,
#     parLapplyLB, parRapply, parSapply, parSapplyLB
#
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: The following objects are masked from ‘package:base’:
#
#     anyDuplicated, append, as.data.frame, basename, cbind, colMeans,
#     colnames, colSums, dirname, do.call, duplicated, eval, evalq,
#     Filter, Find, get, grep, grepl, intersect, is.unsorted, lapply,
#     lengths, Map, mapply, match, mget, order, paste, pmax, pmax.int,
#     pmin, pmin.int, Position, rank, rbind, Reduce, rowMeans, rownames,
#     rowSums, sapply, setdiff, sort, table, tapply, union, unique,
#     unsplit, which, which.max, which.min
#
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: Loading required package: S4Vectors
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: Loading required package: stats4
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning:
# Attaching package: ‘S4Vectors’
#
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: The following object is masked from ‘package:base’:
#
#     expand.grid
#
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: Loading required package: IRanges
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: Loading required package: GenomicRanges
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: Loading required package: Biostrings
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: Loading required package: XVector
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning:
# Attaching package: ‘Biostrings’
#
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: The following object is masked from ‘package:base’:
#
#     strsplit
#
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: Loading required package: Biobase
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: Want to understand how all the pieces fit together? See the R for Data
# Science book: http://r4ds.had.co.nz/
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: Loading required package: SummarizedExperiment
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: Loading required package: DelayedArray
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: Loading required package: matrixStats
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning:
# Attaching package: ‘matrixStats’
#
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: The following objects are masked from ‘package:Biobase’:
#
#     anyMissing, rowMedians
#
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: Loading required package: BiocParallel
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning:
# Attaching package: ‘DelayedArray’
#
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: The following objects are masked from ‘package:matrixStats’:
#
#     colMaxs, colMins, colRanges, rowMaxs, rowMins, rowRanges
#
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: The following object is masked from ‘package:Biostrings’:
#
#     type
#
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: The following objects are masked from ‘package:base’:
#
#     aperm, apply
#
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning:
#
#   warnings.warn(x, RRuntimeWarning)

# %%
# %%R
#
# experiment_groups <- as.list(unique(datadf[['Group']]))
# for (exp_group in experiment_groups){
#
#     group_dir <- paste0('./Experiment_out','/',exp_group)
#     dir.create(paste0(group_dir,'/'))
#
#     n_mods <- 10
#
#     modnames<-sapply(0:9, function(i) paste0('mod_',i))
#     samplesheet <- data.frame(list(modnames, modnames, rep(1, 10), rep('Ctr', 10), rep(1,10), rep('macs', 10)))
#     colnames(samplesheet)<-c('SampleID', 'Tissue', 'Factor', 'Condition', 'Replicate', 'PeakCaller')
#     write.csv(samplesheet, paste0(group_dir,'/','SampleSheet.csv'), row.names=FALSE)
#     replicas <- as.list(unique(datadf[['Experiment']]))
#
#     for (replica in replicas){
#         replica_df <- subset(datadf, Experiment == replica)
#         peaks <- as.list(unique(replica_df[['Peak']]))
#         patterns <- as.list(unique(replica_df[['Pattern']]))
#
#         for (pattern in patterns) {
#             ExperimentData <- list(genome='none',
#                                     dataDir='.',
#                                     sampleSheet =paste0(group_dir,'/','SampleSheet.csv'))
#             MetaData <- list('ExpData' = ExperimentData)
#             MMD <- DBAmmd(MetaData)
#
#             peak_df <- data.frame(chr=c(0:(length(peaks)-1)))
#             peak_df$start <- 0
#             peak_df$end <- 3300
#             regions <- makeGRangesFromDataFrame(peak_df)
#             MMD <- setRegions(MMD, regions)
#
#             Meta <- metaData(MMD)
#             Meta$AnaData$pairedEnd <- rep(FALSE, n_mods)
#             Meta$AnaData$PeakBoundary <- 200
#             MMD@MetaData <- Meta
#             ################################
#             pattern_df = subset(replica_df, Pattern == pattern)
#             dir.create(paste0(group_dir,"/",replica))
#             dirname <- paste0(group_dir,"/",replica,"/",pattern)
#             dir.create(dirname)
#
#             read_data = by(data = pattern_df$Path,
#                             INDICES=pattern_df$Peak,
#                             FUN=function(x) data.frame(read.csv(file=paste(x), header=TRUE, sep=",")))
#
#             readList <- list()
#             rawCounts = matrix(, nrow = length(peaks), ncol = n_mods)
#             rnames <-c()
#             cnames <-c()
#
#             for (i in c(0:(length(peaks)-1))){
#                 rnames <-c(rnames, paste("chr",i, ":0-3300",sep=""))
#             }
#
#             for(i in c(0:(n_mods-1))) {
#                 cnames <-c(cnames, paste("mod_",i, sep=""))
#             }
#
#             rownames(rawCounts) <- rnames
#             colnames(rawCounts) <- cnames
#
#             for(i in c(0:(n_mods-1))) {
#                 col <- paste("mod_",i, sep="")
#                 tempList = list()
#                 j<-0
#                 for(peak in peaks){
#                     row<-paste("chr",j, ":0-3300",sep="")
#                     df<-subset(read_data[[peak]], modification==i)
#                     tempList[[row]]<-(as.numeric(df$position)+200+1)
#                     rawCounts[row, col] <- nrow(df)
#                     j<-j+1
#                 }
#                 readList[[col]] <- tempList
#             }
#
#             MMD@Reads <- list('Center'=readList)
#             MMD@RawTotalCounts = rawCounts
#             MMD <- compDists(MMD,dist.method='MMD2', background_intensity=0.35)
#             MMD <- compDists(MMD,dist.method='MMD')
#             dists <-MMD@DISTs$MMD
#             dists2 <-MMD@DISTs$MMD2
#             write.csv(dists, file = paste0(dirname, "/MMD_old_dists.csv"))
#             write.csv(dists2, file = paste0(dirname, "/MMD_dists.csv"))
#         }
#     }
# }
# Out:
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: checking parameters...
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: computing all distances
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: preparing negative contrast...
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: estimating sigma...
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: computing 45 pair-wise distances...
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: computing distances for mod_0 vs mod_1
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: computing distances for mod_0 vs mod_2
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: computing distances for mod_0 vs mod_3
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: computing distances for mod_0 vs mod_4
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: computing distances for mod_0 vs mod_5
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: computing distances for mod_0 vs mod_6
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: computing distances for mod_0 vs mod_7
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: computing distances for mod_0 vs mod_8
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: computing distances for mod_0 vs mod_9
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: computing distances for mod_1 vs mod_2
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: computing distances for mod_1 vs mod_3
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: computing distances for mod_1 vs mod_4
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: computing distances for mod_1 vs mod_5
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: computing distances for mod_1 vs mod_6
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: computing distances for mod_1 vs mod_7
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: computing distances for mod_1 vs mod_8
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: computing distances for mod_1 vs mod_9
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: computing distances for mod_2 vs mod_3
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: computing distances for mod_2 vs mod_4
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: computing distances for mod_2 vs mod_5
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: computing distances for mod_2 vs mod_6
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: computing distances for mod_2 vs mod_7
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: computing distances for mod_2 vs mod_8
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: computing distances for mod_2 vs mod_9
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: computing distances for mod_3 vs mod_4
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: computing distances for mod_3 vs mod_5
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: computing distances for mod_3 vs mod_6
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: computing distances for mod_3 vs mod_7
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: computing distances for mod_3 vs mod_8
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: computing distances for mod_3 vs mod_9
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: computing distances for mod_4 vs mod_5
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: computing distances for mod_4 vs mod_6
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: computing distances for mod_4 vs mod_7
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: computing distances for mod_4 vs mod_8
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: computing distances for mod_4 vs mod_9
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: computing distances for mod_5 vs mod_6
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: computing distances for mod_5 vs mod_7
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: computing distances for mod_5 vs mod_8
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: computing distances for mod_5 vs mod_9
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: computing distances for mod_6 vs mod_7
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: computing distances for mod_6 vs mod_8
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: computing distances for mod_6 vs mod_9
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: computing distances for mod_7 vs mod_8
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: computing distances for mod_7 vs mod_9
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: computing distances for mod_8 vs mod_9
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: preparing Output...
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/dhelekal/anaconda3/envs/py35v3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: pre-computing Kernel matrix...
#
#   warnings.warn(x, RRuntimeWarning)
